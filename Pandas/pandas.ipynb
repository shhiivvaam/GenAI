# %%
# Pandas -> It is a fast, powerfull, flexible and easy to use open source data analysis and manipulation tool built on top of python.
import pandas as pd

# %%
df = pd.read_csv('services.csv')   # used to read { comma seperated values -> CSV file} into a DataFrame
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1                     NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
#
#   languages                              name required_documents  \
# 0       NaN   Fair Oaks Adult Activity Center                NaN
# 1       NaN  Second Career Employment Program                NaN
#
#       service_areas  status wait_time website taxonomy_ids
# 0             Colma  active  No wait.     NaN          NaN
# 1  San Mateo County  active   Varies.     NaN          NaN
#
# [2 rows x 22 columns]

# %%
# header -> when we want to include the header(title section) of the csv file as a row

df = pd.read_csv("services.csv", header=None)    # the top section will now be treated as the row only and not the title(header)
df.head(3)

# internel integer indexes are provided by pandas
# and this not only generates the indexes for columns, but for rows also
# Out:
#    0            1           2                  3               4   \
# 0  id  location_id  program_id  accepted_payments  alternate_name
# 1   1            1         NaN                NaN             NaN
# 2   2            2         NaN                NaN             NaN
#
#                                    5   \
# 0                 application_process
# 1          Walk in or apply by phone.
# 2  Apply by phone for an appointment.
#
#                                                   6   \
# 0                                           audience
# 1  Older adults age 55 or over, ethnic minorities...
# 2       Residents of San Mateo County age 55 or over
#
#                                                   7   \
# 0                                        description
# 1  A walk-in center for older adults that provide...
# 2  Provides training and job placement to eligibl...
#
#                                                   8      9   ...  \
# 0                                        eligibility  email  ...
# 1  Age 55 or over for most programs, age 60 or ov...    NaN  ...
# 2  Age 55 or over, county resident and willing an...    NaN  ...
#
#                         12                                                 13  \
# 0  interpretation_services                                           keywords
# 1                      NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 2                      NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
#
#           14                                15                  16  \
# 0  languages                              name  required_documents
# 1        NaN   Fair Oaks Adult Activity Center                 NaN
# 2        NaN  Second Career Employment Program                 NaN
#
#                  17      18         19       20            21
# 0     service_areas  status  wait_time  website  taxonomy_ids
# 1             Colma  active   No wait.      NaN           NaN
# 2  San Mateo County  active    Varies.      NaN           NaN
#
# [3 rows x 22 columns]

# %%
# skiprows       -> when we want to skip some starting rows

df = pd.read_csv("services.csv", skiprows=1)    # this will result in skipping the first { 3 } rows including the header section(title section -> top level section in a CSV file where the title for the rows are defined)
df.head(3)
# Out:
#    1  1.1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  2    2         NaN        NaN        NaN
# 1  3    3         NaN        NaN        NaN
# 2  4    4         NaN        NaN        NaN
#
#                     Walk in or apply by phone.  \
# 0           Apply by phone for an appointment.
# 1  Phone for information (403-4300 Ext. 4322).
# 2                              Apply by phone.
#
#   Older adults age 55 or over, ethnic minorities and low-income persons  \
# 0       Residents of San Mateo County age 55 or over
# 1  Older adults age 55 or over who can benefit fr...
# 2  Parents, children, families with problems of c...
#
#   A walk-in center for older adults that provides social services, wellness, recreational, educational and creative activities including arts and crafts, computer classes and gardening classes.  \
# 0  Provides training and job placement to eligibl...
# 1  Offers supportive counseling services to San M...
# 2  Provides supervised visitation services and a ...
#
#   Age 55 or over for most programs, age 60 or over for lunch program  \
# 0  Age 55 or over, county resident and willing an...
# 1        Resident of San Mateo County age 55 or over
# 2                                                NaN
#
#   Unnamed: 9  ... Unnamed: 12  \
# 0        NaN  ...         NaN
# 1        NaN  ...         NaN
# 2        NaN  ...         NaN
#
#   ADULT PROTECTION AND CARE SERVICES, Meal Sites/Home-delivered Mea, COMMUNITY SERVICES, Group Support, Information and Referral, EDUCATION SERVICES, English Language, RECREATION/LEISURE SERVICES, Arts and Crafts, Sports/Games/Exercise, Brown Bag Food Programs, Congregate Meals/Nutrition Sites, Senior Centers, Older Adults  \
# 0  EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 1  Geriatric Counseling, Older Adults, Gay, Lesbi...
# 2  INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...
#
#   Unnamed: 14   Fair Oaks Adult Activity Center Unnamed: 16             Colma  \
# 0         NaN  Second Career Employment Program         NaN  San Mateo County
# 1         NaN            Senior Peer Counseling         NaN  San Mateo County
# 2         NaN          Family Visitation Center         NaN  San Mateo County
#
#    active  No wait. Unnamed: 20 Unnamed: 21
# 0  active   Varies.         NaN         NaN
# 1  active   Varies.         NaN         NaN
# 2  active  No wait.         NaN         NaN
#
# [3 rows x 22 columns]

# %%
# when we want to read only some desired columns

df = pd.read_csv("services.csv", usecols=['program_id', 'application_process'])    
df.head(5)
# Out:
#    program_id                          application_process
# 0         NaN                   Walk in or apply by phone.
# 1         NaN           Apply by phone for an appointment.
# 2         NaN  Phone for information (403-4300 Ext. 4322).
# 3         NaN                              Apply by phone.
# 4         NaN                       Phone for information.

# %%
df = pd.read_csv("services.csv")         # here the { df } will contain the DataFrame generated from the CSV file
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
# 2        Resident of San Mateo County age 55 or over   NaN  ...
#
#   interpretation_services                                           keywords  \
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1                     NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 2                     NaN  Geriatric Counseling, Older Adults, Gay, Lesbi...
#
#   languages                              name required_documents  \
# 0       NaN   Fair Oaks Adult Activity Center                NaN
# 1       NaN  Second Career Employment Program                NaN
# 2       NaN            Senior Peer Counseling                NaN
#
#       service_areas  status wait_time website taxonomy_ids
# 0             Colma  active  No wait.     NaN          NaN
# 1  San Mateo County  active   Varies.     NaN          NaN
# 2  San Mateo County  active   Varies.     NaN          NaN
#
# [3 rows x 22 columns]

# %%
# Data Structures    -> dataframe and series
        # series : 1 dimensional in nature
        # dataframe : 2 dimensional in nature, multiple series constitutes to form a dataframe

# %%
print(type(df))
print(type(df.application_process))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
df.application_process
# df['application_process']
# Out:
# 0                            Walk in or apply by phone.
# 1                    Apply by phone for an appointment.
# 2           Phone for information (403-4300 Ext. 4322).
# 3                                       Apply by phone.
# 4                                Phone for information.
# 5     Walk in or apply by phone for membership appli...
# 6     Apply by phone or be referred by a doctor, soc...
# 7                                       Apply by phone.
# 8     Walk in. Proof of residency in California requ...
# 9     Walk in. Proof of California residency to rece...
# 10    Walk in. Proof of California residency require...
# 11    Walk in or apply by phone, email or webpage re...
# 12    Walk in. Proof of California residency require...
# 13    Call for appointment. Referral from human serv...
# 14            Walk in or through other agency referral.
# 15    Walk in. Written application, identification r...
# 16                                Call for information.
# 17    Call for screening appointment. Medical visits...
# 18       Call for screening appointment (650-347-3648).
# 19                                             Walk in.
# 20                      By phone during business hours.
# 21                    Walk in or apply by phone or mail
# 22                    Walk in or apply by phone or mail
# Name: application_process, dtype: object

# %%
l = [1,2,3,4]
s = pd.Series(l)
print(type(s))
s
# Out:
# <class 'pandas.core.series.Series'>
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
print(s[:3])
s[0]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64
# 1

# %%
d = pd.Series([100, 200, 300], index=["Ajay", "Bijay", "Sanjay"])
d
# Out:
# Ajay      100
# Bijay     200
# Sanjay    300
# dtype: int64

# %%
print(d.iloc[0])
d["Ajay"]
# Out:
# 100
# 100

# %%
d.index
# Out:
# Index(['Ajay', 'Bijay', 'Sanjay'], dtype='object')

# %%
d["Ajay": "Sanjay"]
# Out:
# Ajay      100
# Bijay     200
# Sanjay    300
# dtype: int64

# %%
d.reset_index(drop=True)        # not including this { drop = True } will lead to the formation of Dataframe -> instead of Series
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
pd.DataFrame(d)       # this will convert the series into a DataFrame
# Out:
#           0
# Ajay    100
# Bijay   200
# Sanjay  300

# %%
df.shape
# Out:
# (23, 22)

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df.sample(2)          # this will return any two rows(ranomly) from the { df } dataframe
# Out:
#     id  location_id  program_id accepted_payments alternate_name  \
# 1    2            2         NaN               NaN            NaN
# 10  11           11         NaN               NaN            NaN
#
#                                   application_process  \
# 1                  Apply by phone for an appointment.
# 10  Walk in. Proof of California residency require...
#
#                                         audience  \
# 1   Residents of San Mateo County age 55 or over
# 10                                           NaN
#
#                                           description  \
# 1   Provides training and job placement to eligibl...
# 10  Provides general reading materials, including ...
#
#                                           eligibility email  ...  \
# 1   Age 55 or over, county resident and willing an...   NaN  ...
# 10  Resident of California to obtain a library car...   NaN  ...
#
#    interpretation_services                                           keywords  \
# 1                      NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 10                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
#
#    languages                              name required_documents  \
# 1        NaN  Second Career Employment Program                NaN
# 10       NaN                   Schaberg Branch                NaN
#
#        service_areas  status wait_time website taxonomy_ids
# 1   San Mateo County  active   Varies.     NaN          NaN
# 10  San Mateo County  active  No wait.     NaN          NaN
#
# [2 rows x 22 columns]

# %%
df.info()                # this is used to get the full information of the dataframe -> including ( datatype, null counts)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       23 non-null     int64
#  1   location_id              23 non-null     int64
#  2   program_id               0 non-null      float64
#  3   accepted_payments        1 non-null      object
#  4   alternate_name           1 non-null      object
#  5   application_process      23 non-null     object
#  6   audience                 14 non-null     object
#  7   description              23 non-null     object
#  8   eligibility              17 non-null     object
#  9   email                    1 non-null      object
#  10  fees                     21 non-null     object
#  11  funding_sources          21 non-null     object
#  12  interpretation_services  1 non-null      object
#  13  keywords                 21 non-null     object
#  14  languages                1 non-null      object
#  15  name                     23 non-null     object
#  16  required_documents       1 non-null      object
#  17  service_areas            21 non-null     object
#  18  status                   23 non-null     object
#  19  wait_time                19 non-null     object
#  20  website                  2 non-null      object
#  21  taxonomy_ids             1 non-null      object
# dtypes: float64(1), int64(2), object(19)
# memory usage: 4.1+ KB

# %%
# Pandas provides the flexibility to read the table of some HTML document (but it is only for table in th HTML file)
# %pip install lxml
import lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in c:\users\lifes\appdata\roaming\python\python312\site-packages (5.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Reading HTML data

url_df = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
print(type(url_df))
url_df
# Out:
# <class 'list'>
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
df4 = url_df[0]
df4
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df4.to_csv("players.csv", index = False)               # index = False means the default indexing in the rows will not be present int the saved versio of the CSV file

# %%
# Reading JSON Data

url = "https://api.github.com/repos/pandas-dev/pandas/issues"
pd.read_json(url).head(5)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url          id  \
# 0    https://github.com/pandas-dev/pandas/pull/58492  2271343475
# 1    https://github.com/pandas-dev/pandas/pull/58491  2271312578
# 2    https://github.com/pandas-dev/pandas/pull/58490  2271264598
# 3    https://github.com/pandas-dev/pandas/pull/58489  2270900324
# 4  https://github.com/pandas-dev/pandas/issues/58488  2270886841
#
#                node_id  number  \
# 0  PR_kwDOAA0YD85uIz86   58492
# 1  PR_kwDOAA0YD85uIs80   58491
# 2  PR_kwDOAA0YD85uIiR3   58490
# 3  PR_kwDOAA0YD85uHSbQ   58489
# 4   I_kwDOAA0YD86HWvu5   58488
#
#                                                title  ... closed_at  \
# 0  DOC: Enforce Numpy Docstring Validation for pa...  ...       NaT
# 1  DOC: Enforce Numpy Docstring Validation for pa...  ...       NaT
# 2  DOC: Enforce Numpy Docstring Validation for pa...  ...       NaT
# 3  DOC: Enforce Numpy Docstring Validation for pa...  ...       NaT
# 4  DOC: User guide still recommends delim_whitespace  ...       NaT
#
#   author_association active_lock_reason  draft  \
# 0        CONTRIBUTOR                NaN    1.0
# 1        CONTRIBUTOR                NaN    1.0
# 2        CONTRIBUTOR                NaN    1.0
# 3        CONTRIBUTOR                NaN    0.0
# 4               NONE                NaN    NaN
#
#                                         pull_request  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4                                                NaN
#
#                                                 body  \
# 0                             - [ ] xref #58065 \r\n
# 1                             - [ ] xref #58065 \r\n
# 2                             - [ ] xref #58068 \r\n
# 3                             - [ ] xref #58068 \r\n
# 4  ### Pandas version checks\n\n- [X] I have chec...
#
#                                            reactions  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                         timeline_url performed_via_github_app  \
# 0  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 1  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 2  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 3  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 4  https://api.github.com/repos/pandas-dev/pandas...                      NaN
#
#   state_reason
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 30 columns]

# %%
# Directly accessign data from requests

import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
resp = requests.get(url)
print(type(resp))
resp
# Out:
# <class 'requests.models.Response'>
# <Response [200]>

# %%
df6 = resp.json()
df6
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58493',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58493/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58493/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58493/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58493',
#   'id': 2271418090,
#   'node_id': 'PR_kwDOAA0YD85uJEaQ',
#   'number': 58493,
#   'title': 'DOC: Enforce Numpy Docstring Validation for pandas.DataFrame.kurt and pandas.DataFrame.kurtosis',
#   'user': {'login': 'tuhinsharma121',
#    'id': 6801780,
#    'node_id': 'MDQ6VXNlcjY4MDE3ODA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tuhinsharma121',
#    'html_url': 'https://github.com/tuhinsharma121',
#    'followers_url': 'https://api.github.com/users/tuhinsharma121/followers',
#    'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs',
#    'repos_url': 'https://api.github.com/users/tuhinsharma121/repos',
#    'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-30T13:02:48Z',
#   'updated_at': '2024-04-30T13:02:48Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58493',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58493',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58493.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58493.patch',
#    'merged_at': None},
#   'body': '- [ ] xref #58065 \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58493/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58493/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58492',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58492/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58492/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58492/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58492',
#   'id': 2271343475,
#   'node_id': 'PR_kwDOAA0YD85uIz86',
#   'number': 58492,
#   'title': 'DOC: Enforce Numpy Docstring Validation for pandas.DataFrame.attime',
#   'user': {'login': 'tuhinsharma121',
#    'id': 6801780,
#    'node_id': 'MDQ6VXNlcjY4MDE3ODA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tuhinsharma121',
#    'html_url': 'https://github.com/tuhinsharma121',
#    'followers_url': 'https://api.github.com/users/tuhinsharma121/followers',
#    'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs',
#    'repos_url': 'https://api.github.com/users/tuhinsharma121/repos',
#    'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-30T12:29:23Z',
#   'updated_at': '2024-04-30T12:29:23Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58492',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58492',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58492.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58492.patch',
#    'merged_at': None},
#   'body': '- [ ] xref #58065 \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58492/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58492/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58491',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58491/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58491/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58491/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58491',
#   'id': 2271312578,
#   'node_id': 'PR_kwDOAA0YD85uIs80',
#   'number': 58491,
#   'title': 'DOC: Enforce Numpy Docstring Validation for pandas.DataFrame.__dataframe__',
#   'user': {'login': 'tuhinsharma121',
#    'id': 6801780,
#    'node_id': 'MDQ6VXNlcjY4MDE3ODA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tuhinsharma121',
#    'html_url': 'https://github.com/tuhinsharma121',
#    'followers_url': 'https://api.github.com/users/tuhinsharma121/followers',
#    'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs',
#    'repos_url': 'https://api.github.com/users/tuhinsharma121/repos',
#    'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-30T12:17:36Z',
#   'updated_at': '2024-04-30T13:03:33Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58491',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58491',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58491.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58491.patch',
#    'merged_at': None},
#   'body': '- [ ] xref #58065 \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58491/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58491/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58490',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58490/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58490/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58490/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58490',
#   'id': 2271264598,
#   'node_id': 'PR_kwDOAA0YD85uIiR3',
#   'number': 58490,
#   'title': 'DOC: Enforce Numpy Docstring Validation for pandas.Index.sliece_indexer',
#   'user': {'login': 'tuhinsharma121',
#    'id': 6801780,
#    'node_id': 'MDQ6VXNlcjY4MDE3ODA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tuhinsharma121',
#    'html_url': 'https://github.com/tuhinsharma121',
#    'followers_url': 'https://api.github.com/users/tuhinsharma121/followers',
#    'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs',
#    'repos_url': 'https://api.github.com/users/tuhinsharma121/repos',
#    'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-30T11:54:53Z',
#   'updated_at': '2024-04-30T13:03:22Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58490',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58490',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58490.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58490.patch',
#    'merged_at': None},
#   'body': '- [ ] xref #58068 \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58490/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58490/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58489',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58489/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58489/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58489/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58489',
#   'id': 2270900324,
#   'node_id': 'PR_kwDOAA0YD85uHSbQ',
#   'number': 58489,
#   'title': 'DOC: Enforce Numpy Docstring Validation for pandas.Index.take',
#   'user': {'login': 'tuhinsharma121',
#    'id': 6801780,
#    'node_id': 'MDQ6VXNlcjY4MDE3ODA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tuhinsharma121',
#    'html_url': 'https://github.com/tuhinsharma121',
#    'followers_url': 'https://api.github.com/users/tuhinsharma121/followers',
#    'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs',
#    'repos_url': 'https://api.github.com/users/tuhinsharma121/repos',
#    'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-30T08:55:14Z',
#   'updated_at': '2024-04-30T09:58:00Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58489',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58489',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58489.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58489.patch',
#    'merged_at': None},
#   'body': '- [ ] xref #58068 \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58489/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58489/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58488',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58488/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58488/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58488/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58488',
#   'id': 2270886841,
#   'node_id': 'I_kwDOAA0YD86HWvu5',
#   'number': 58488,
#   'title': 'DOC: User guide still recommends delim_whitespace',
#   'user': {'login': 'edbennett',
#    'id': 1698405,
#    'node_id': 'MDQ6VXNlcjE2OTg0MDU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1698405?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/edbennett',
#    'html_url': 'https://github.com/edbennett',
#    'followers_url': 'https://api.github.com/users/edbennett/followers',
#    'following_url': 'https://api.github.com/users/edbennett/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/edbennett/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/edbennett/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/edbennett/subscriptions',
#    'organizations_url': 'https://api.github.com/users/edbennett/orgs',
#    'repos_url': 'https://api.github.com/users/edbennett/repos',
#    'events_url': 'https://api.github.com/users/edbennett/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/edbennett/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-04-30T08:49:28Z',
#   'updated_at': '2024-04-30T11:13:46Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/dev/user_guide/io.html#basic\n\n### Documentation problem\n\nWhile the main API reference indicates that the `delim_whitespace` option to `pandas.read_csv` is deprecated, the User Guide still lists it as an option with no caveat. This may lead new users to adopt an option that is already deprecated, and either immediately get warnings, or write code that will break relatively soon.\n\n### Suggested fix for documentation\n\nEither remove the `delim_whitespace` option from the page (probably preferred; new users don't need to be introduced to features about to be deprecated) or add a deprecation notice similar to the one appearing on [the `read_csv` reference](https://pandas.pydata.org/docs/dev/reference/api/pandas.read_csv.html#pandas.read_csv)",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58488/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58488/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58487',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58487/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58487/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58487/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58487',
#   'id': 2270878259,
#   'node_id': 'I_kwDOAA0YD86HWtoz',
#   'number': 58487,
#   'title': 'DOC: delim_whitespace deprecation warning advocates code that generates a warning in Python 3.12',
#   'user': {'login': 'edbennett',
#    'id': 1698405,
#    'node_id': 'MDQ6VXNlcjE2OTg0MDU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1698405?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/edbennett',
#    'html_url': 'https://github.com/edbennett',
#    'followers_url': 'https://api.github.com/users/edbennett/followers',
#    'following_url': 'https://api.github.com/users/edbennett/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/edbennett/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/edbennett/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/edbennett/subscriptions',
#    'organizations_url': 'https://api.github.com/users/edbennett/orgs',
#    'repos_url': 'https://api.github.com/users/edbennett/repos',
#    'events_url': 'https://api.github.com/users/edbennett/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/edbennett/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-04-30T08:44:59Z',
#   'updated_at': '2024-04-30T11:48:46Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\n`pandas.read_csv` and https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html\n\n### Documentation problem\n\nThe deprecation warning for the `delim_whitespace` option suggests using `sep="\\s+"` instead. Since `\\s` is not a valid escape sequence, in Python 3.11 and earlier this is equivalent to `sep=r"\\s+"`.\r\n\r\nHowever, in Python 3.12, invalid escape sequences now generate `SyntaxWarning`s. I would suggest that Pandas should avoid advising users to add code that will generate warnings (in particular when doing so via a warning—if the suggestion is implemented, then the number of warnings would remain constant rather than decreasing)\n\n### Suggested fix for documentation\n\nReplace all instances of `sep="\\s+"` with either `sep=r"\\s+"` or `sep="\\\\s+"`.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58487/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58487/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58486',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58486/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58486/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58486/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58486',
#   'id': 2270806519,
#   'node_id': 'PR_kwDOAA0YD85uG9qP',
#   'number': 58486,
#   'title': 'DOC: Enforce Numpy Docstring Validation for pandas.Index.view',
#   'user': {'login': 'tuhinsharma121',
#    'id': 6801780,
#    'node_id': 'MDQ6VXNlcjY4MDE3ODA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tuhinsharma121',
#    'html_url': 'https://github.com/tuhinsharma121',
#    'followers_url': 'https://api.github.com/users/tuhinsharma121/followers',
#    'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs',
#    'repos_url': 'https://api.github.com/users/tuhinsharma121/repos',
#    'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-30T08:11:44Z',
#   'updated_at': '2024-04-30T11:29:45Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58486',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58486',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58486.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58486.patch',
#    'merged_at': None},
#   'body': '- [ ] xref #58068 \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58486/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58486/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58485',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58485/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58485/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58485/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58485',
#   'id': 2270793020,
#   'node_id': 'I_kwDOAA0YD86HWY08',
#   'number': 58485,
#   'title': "BUG: DataFrame `convert_dtype='pyarrow'` with int64_t limits throws Warning",
#   'user': {'login': 'Tishj',
#    'id': 17162323,
#    'node_id': 'MDQ6VXNlcjE3MTYyMzIz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17162323?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Tishj',
#    'html_url': 'https://github.com/Tishj',
#    'followers_url': 'https://api.github.com/users/Tishj/followers',
#    'following_url': 'https://api.github.com/users/Tishj/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Tishj/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Tishj/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Tishj/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Tishj/orgs',
#    'repos_url': 'https://api.github.com/users/Tishj/repos',
#    'events_url': 'https://api.github.com/users/Tishj/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Tishj/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-30T08:05:35Z',
#   'updated_at': '2024-04-30T11:43:42Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nimport pyarrow as pa\r\n\r\nprint(pd.__version__)\r\nprint(pa.__version__)\r\n\r\ndf = pd.DataFrame({\r\n\t'a': [-9223372036854775808, 4611686018427387904, 9223372036854775807, None],\r\n\t'b': [-9223372036854775808, 4611686018427387904, 9223372036854775807, None],\r\n\t'c': [-9223372036854775808, 4611686018427387904, 9223372036854775807, None],\r\n})\r\n\r\npa_df = df.convert_dtypes(dtype_backend='pyarrow')\r\nprint(pa_df)\r\n```\r\n```\r\n2.2.2\r\n16.0.0\r\n/Users/User/.pyenv/versions/3.12.1/lib/python3.12/site-packages/pandas/core/dtypes/cast.py:1057: RuntimeWarning: invalid value encountered in cast\r\n  if (arr.astype(int) == arr).all():\r\n/Users/User/.pyenv/versions/3.12.1/lib/python3.12/site-packages/pandas/core/dtypes/cast.py:1081: RuntimeWarning: invalid value encountered in cast\r\n  if (arr.astype(int) == arr).all():\r\n                      a                     b                     c\r\n0  -9223372036854775808  -9223372036854775808  -9223372036854775808\r\n1   4611686018427387904   4611686018427387904   4611686018427387904\r\n2   9223372036854775807   9223372036854775807   9223372036854775807\r\n3                  <NA>                  <NA>                  <NA>\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nThrowing a warning when converting\r\n\r\n### Expected Behavior\r\n\r\nIt should not throw a warning, it looks like the conversion happens successfully in spite of the warning.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\ncommit                : d9cdd2ee5a58015ef6f4d15c7226110c9aab8140\r\npython                : 3.12.1.final.0\r\npython-bits           : 64\r\nOS                    : Darwin\r\nOS-release            : 23.1.0\r\nVersion               : Darwin Kernel Version 23.1.0: Mon Oct  9 21:28:45 PDT 2023; root:xnu-10002.41.9~6/RELEASE_ARM64_T6020\r\nmachine               : arm64\r\nprocessor             : arm\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : en_US.UTF-8\r\nLOCALE                : en_US.UTF-8\r\n\r\npandas                : 2.2.2\r\nnumpy                 : 1.26.4\r\npytz                  : 2024.1\r\ndateutil              : 2.8.2\r\nsetuptools            : 69.5.1\r\npip                   : 23.2.1\r\nCython                : None\r\npytest                : 8.1.1\r\nhypothesis            : None\r\nsphinx                : None\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : None\r\nlxml.etree            : None\r\nhtml5lib              : None\r\npymysql               : None\r\npsycopg2              : None\r\njinja2                : 3.1.3\r\nIPython               : None\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : None\r\nbottleneck            : None\r\ndataframe-api-compat  : None\r\nfastparquet           : None\r\nfsspec                : 2024.3.1\r\ngcsfs                 : None\r\nmatplotlib            : None\r\nnumba                 : None\r\nnumexpr               : None\r\nodfpy                 : None\r\nopenpyxl              : None\r\npandas_gbq            : None\r\npyarrow               : 16.0.0\r\npyreadstat            : None\r\npython-calamine       : None\r\npyxlsb                : None\r\ns3fs                  : None\r\nscipy                 : None\r\nsqlalchemy            : 2.0.29\r\ntables                : None\r\ntabulate              : None\r\nxarray                : None\r\nxlrd                  : None\r\nzstandard ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58485/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58485/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58484',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58484/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58484/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58484/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58484',
#   'id': 2270415980,
#   'node_id': 'PR_kwDOAA0YD85uFogl',
#   'number': 58484,
#   'title': 'Remove deprecated plot_date calls',
#   'user': {'login': 'QuLogic',
#    'id': 302469,
#    'node_id': 'MDQ6VXNlcjMwMjQ2OQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/302469?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/QuLogic',
#    'html_url': 'https://github.com/QuLogic',
#    'followers_url': 'https://api.github.com/users/QuLogic/followers',
#    'following_url': 'https://api.github.com/users/QuLogic/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/QuLogic/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/QuLogic/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/QuLogic/subscriptions',
#    'organizations_url': 'https://api.github.com/users/QuLogic/orgs',
#    'repos_url': 'https://api.github.com/users/QuLogic/repos',
#    'events_url': 'https://api.github.com/users/QuLogic/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/QuLogic/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-04-30T03:15:47Z',
#   'updated_at': '2024-04-30T04:54:49Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58484',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58484',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58484.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58484.patch',
#    'merged_at': None},
#   'body': 'These were deprecated in Matplotlib 3.9.\r\n\r\n- [n/a] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [n/a] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58484/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58484/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58483',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58483/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58483/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58483/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58483',
#   'id': 2270309742,
#   'node_id': 'PR_kwDOAA0YD85uFR8T',
#   'number': 58483,
#   'title': 'CLN: Simplify map_infer_mask',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-30T01:23:11Z',
#   'updated_at': '2024-04-30T03:43:51Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58483',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58483',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58483.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58483.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\n\r\nThis is needed for upcoming numpy string dtype support (getting rid of the ``ndarray[object]`` annotation).\r\n\r\nWe might also get a decent speedup from using numpy C API functions (but probably not).\r\n\r\nEDIT: Looks like benchmarks aren't significantly changed.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58483/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58483/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58482',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58482/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58482/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58482/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/58482',
#   'id': 2270151223,
#   'node_id': 'I_kwDOAA0YD86HT8I3',
#   'number': 58482,
#   'title': "BUG: DataFrame's loc set works incorrectly with scalar column key and single value DataFrame item",
#   'user': {'login': 'sfc-gh-vbudati',
#    'id': 136361283,
#    'node_id': 'U_kgDOCCC1Qw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136361283?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sfc-gh-vbudati',
#    'html_url': 'https://github.com/sfc-gh-vbudati',
#    'followers_url': 'https://api.github.com/users/sfc-gh-vbudati/followers',
#    'following_url': 'https://api.github.com/users/sfc-gh-vbudati/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sfc-gh-vbudati/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sfc-gh-vbudati/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sfc-gh-vbudati/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sfc-gh-vbudati/orgs',
#    'repos_url': 'https://api.github.com/users/sfc-gh-vbudati/repos',
#    'events_url': 'https://api.github.com/users/sfc-gh-vbudati/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sfc-gh-vbudati/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-29T23:17:54Z',
#   'updated_at': '2024-04-29T23:17:54Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\ndf = pd.DataFrame(\r\n    [\r\n        [91, -2, 83, 74], \r\n        [95, -6, 87, 78], \r\n        [99, -10, 811, 712], \r\n        [913, -14, 815, 716]\r\n    ],\r\n    index=["x", "x", "z", "w"],\r\n    columns=["A", "B", "C", "D"],\r\n    dtype=float\r\n)\r\n\r\n# item assigned\r\nitem = pd.DataFrame([100], columns=["A"], index=["v"])\r\n\r\n# scalar column key\r\ndf.loc[:, "A"] = item\n```\n\n\n### Issue Description\n\nThis is an issue that exist in pandas versions 2.x+ in the DataFrame loc set functionality. \r\n\r\nWhen a column key is supplied to loc set and the item it is set to is a DataFrame object:\r\n- if the column key is a scalar value, the assignment of values is done based on position, i.e., the first column from the DataFrame item is assigned to the first column in the original DataFrame.\r\nFor example,\r\n```py\r\ndf = pd.DataFrame(\r\n    {\r\n        "A": [1, 2, 3], \r\n        "B": [4, 5, 6], \r\n        "C": [7, 8, 9]\r\n    }\r\n)\r\n\r\nitem = pd.DataFrame({"C": [10, 20, 30]})\r\n\r\n# Result df - assignment by position\r\ndf.loc[:, "A"] = item\r\n    A  B  C\r\n0  10  4  7\r\n1  20  5  8\r\n2  30  6  9\r\n```\r\n- if the column key is a list-like value, the assignment of values is done by matching the column names from the item DataFrame to the original DataFrame.\r\nFor example,\r\n```py\r\n# Given a DataFrame df\r\ndf = pd.DataFrame(\r\n    {\r\n        "A": [1, 2, 3], \r\n        "B": [4, 5, 6], \r\n        "C": [7, 8, 9]\r\n    }\r\n)\r\n\r\nitem = pd.DataFrame(\r\n    {\r\n        "C": [10, 20, 30], \r\n        "B": [40, 50, 60], \r\n        "A": [70, 80, 90]\r\n    }\r\n)\r\n\r\n# Using a list-like column key\r\ndf.loc[:, ["A", "B", "C"]] = item\r\n# Result df - assignment by labels\r\n    A   B   C\r\n0  70  40  10\r\n1  80  50  20\r\n2  90  60  30\r\n```\r\n\r\nThis logic is not being followed in the example provided in the Reproducible Example section.\r\nThe output produced by the reproducible example is:\r\n```py\r\n       A     B      C      D\r\nx  100.0  -2.0   83.0   74.0\r\nx  100.0  -6.0   87.0   78.0\r\nz  100.0 -10.0  811.0  712.0\r\nw  100.0 -14.0  815.0  716.0\r\n```\r\ninstead of:\r\n```py\r\n    A     B      C      D\r\nx NaN  -2.0   83.0   74.0\r\nx NaN  -6.0   87.0   78.0\r\nz NaN -10.0  811.0  712.0\r\nw NaN -14.0  815.0  716.0\r\n```\r\n\r\nIt is apparent that this is a bug since using the `item` below produces the correct result:\r\n```py\r\n# new item assigned\r\nitem = pd.DataFrame([100, 101], columns=["A"], index=["v", "z"])\r\n\r\n# scalar column key\r\ndf.loc[:, "A"] = item\r\n\r\n# Result df:\r\n       A     B      C      D\r\nx    NaN  -2.0   83.0   74.0\r\nx    NaN  -6.0   87.0   78.0\r\nz  101.0 -10.0  811.0  712.0\r\nw    NaN -14.0  815.0  716.0\r\n```\n\n### Expected Behavior\n\nThe output produced by the reproducible example is:\r\n```py\r\n       A     B      C      D\r\nx  100.0  -2.0   83.0   74.0\r\nx  100.0  -6.0   87.0   78.0\r\nz  100.0 -10.0  811.0  712.0\r\nw  100.0 -14.0  815.0  716.0\r\n```\r\n(expected behavior) instead of:\r\n```py\r\n    A     B      C      D\r\nx NaN  -2.0   83.0   74.0\r\nx NaN  -6.0   87.0   78.0\r\nz NaN -10.0  811.0  712.0\r\nw NaN -14.0  815.0  716.0\r\n```\r\n\r\nmore details in the Issue Description section.\n\n### Installed Versions\n\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : bdc79c146c2e32f2cab629be240f01658cfb6cc2\r\npython                : 3.11.9.final.0\r\npython-bits           : 64\r\nOS          ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58482/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58482/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58481',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58481/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58481/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58481/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58481',
#   'id': 2270122901,
#   'node_id': 'PR_kwDOAA0YD85uEoQG',
#   'number': 58481,
#   'title': 'BUG: hashing read only object categories raises',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1654197779,
#     'node_id': 'MDU6TGFiZWwxNjU0MTk3Nzc5',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/hashing',
#     'name': 'hashing',
#     'color': '6beae0',
#     'default': False,
#     'description': 'hash_pandas_object'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/102',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels',
#    'id': 9021906,
#    'node_id': 'MI_kwDOAA0YD84AianS',
#    'number': 102,
#    'title': '3.0',
#    'description': '',
#    'creator': {'login': 'jbrockmendel',
#     'id': 8078968,
#     'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jbrockmendel',
#     'html_url': 'https://github.com/jbrockmendel',
#     'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#     'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
# ...
#    'following_url': 'https://api.github.com/users/jowens/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jowens/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jowens/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jowens/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jowens/orgs',
#    'repos_url': 'https://api.github.com/users/jowens/repos',
#    'events_url': 'https://api.github.com/users/jowens/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jowens/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 57395487,
#     'node_id': 'MDU6TGFiZWw1NzM5NTQ4Nw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20HTML',
#     'name': 'IO HTML',
#     'color': '006b75',
#     'default': False,
#     'description': 'read_html, to_html, Styler.apply, Styler.applymap'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 9,
#   'created_at': '2024-04-28T03:33:07Z',
#   'updated_at': '2024-04-29T14:43:58Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n#!/usr/bin/env python3\r\n\r\nimport pandas as pd\r\nimport re\r\nimport requests\r\nfrom io import StringIO\r\n\r\npd.set_option("display.max_columns", None)\r\npd.set_option("display.max_rows", None)\r\npd.set_option("display.width", 500)\r\n\r\nhtml = requests.get(\r\n    "https://en.wikipedia.org/wiki/Template:AMD_Radeon_Pro_V_series"\r\n).text\r\n\r\ndf = pd.read_html(\r\n    StringIO(html),\r\n    match=re.compile("Radeon Pro V620"),\r\n)\r\nprint(df)\n```\n\n\n### Issue Description\n\nThe bottom right of the ingested table puts entries in the wrong columns near the right side for the last two rows. I did some checking of the HTML source and even though it\'s got some complex rowspan and colspan directives, it appears to be properly constructed.\r\n\r\n<img width="2198" alt="Cursor_and___Documents_working_owensgroup_proj_gpustats__jowens_piecaken" src="https://github.com/pandas-dev/pandas/assets/976970/dfecc613-b159-41fe-8326-14980f0e3239">\r\n<img width="1342" alt="Template_AMD_Radeon_Pro_V_series_-_Wikipedia" src="https://github.com/pandas-dev/pandas/assets/976970/e7223947-056d-4f5e-a5f8-e8115aba3d67">\r\n\r\nI acknowledge that I\'m using a slightly older pandas than is installed, but I looked through recent issues on and checkins to `read_html` and I don\'t believe this is fixed/reported.\n\n### Expected Behavior\n\nI expect the column called "Memory / L3 Cache" to only be populated in the last row.\r\n\r\nI expect the two power entries in the last two rows to be placed in the "TDP" column.\r\n\r\nMost of the right side of the bottom two rows is misplaced.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : bdc79c146c2e32f2cab629be240f01658cfb6cc2\r\npython                : 3.12.3.final.0\r\npython-bits           : 64\r\nOS                    : Darwin\r\nOS-release            : 23.4.0\r\nVersion               : Darwin Kernel Version 23.4.0: Fri Mar 15 00:10:42 PDT 2024; root:xnu-10063.101.17~1/RELEASE_ARM64_T6000\r\nmachine               : arm64\r\nprocessor             : arm\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : en_US.UTF-8\r\nLOCALE                : en_US.UTF-8\r\n\r\npandas                : 2.2.1\r\nnumpy                 : 1.26.4\r\npytz                  : 2024.1\r\ndateutil              : 2.8.2\r\nsetuptools            : 69.5.1\r\npip                   : 24.0\r\nCython                : 3.0.10\r\npytest                : 7.4.3\r\nhypothesis            : None\r\nsphinx                : 7.2.6\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : None\r\nlxml.etree            : 5.2.1\r\nhtml5lib              : 1.1\r\npymysql               : None\r\npsycopg2              : None\r\njinja2                : 3.1.3\r\nIPython               : 8.23.0\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : 4.12.2\r\nbottleneck            : None\r\ndataframe-api-compat  : None\r\nfastparquet           : None\r\nfsspec                : None\r\ngcsfs                 : None\r\nmatplotlib            : None\r\nnumba                 : None\r\nnumexpr               : None\r\nodfpy                 : None\r\nopenpyxl              : None\r\npandas_gbq            : None\r\npyarrow               : 13.0.0.dev0+gb7d2f7ffc.d20240415\r\npyreadstat            : None\r\npython-calamine       : None\r\npyxlsb                : None\r\ns3fs                  : None\r\nscipy     ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58461/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58461/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58459',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58459/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58459/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58459/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58459',
#   'id': 2267150044,
#   'node_id': 'PR_kwDOAA0YD85t6hd_',
#   'number': 58459,
#   'title': 'TST / string dtype: add env variable to enable future_string and add test build',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 57522093,
#     'node_id': 'MDU6TGFiZWw1NzUyMjA5Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Strings',
#     'name': 'Strings',
#     'color': '5319e7',
#     'default': False,
#     'description': 'String extension data type and string data'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-04-27T19:12:02Z',
#   'updated_at': '2024-04-28T04:40:58Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58459',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58459',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58459.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58459.patch',
#    'merged_at': None},
#   'body': 'xref https://github.com/pandas-dev/pandas/issues/54792\r\n\r\nTaking a similar approach as we did for CoW: allow enabling the option with an env variable (also useful for testing locally), and add an extra build on CI with that option enabled. \r\n\r\nNot all tests are passing yet, so will see how to mark this build as "allow failures", but I think it would already be useful to set up the infra so we can fix the tests piecewise in follow-ups.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58459/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58459/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58458',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58458/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58458/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58458/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58458',
#   'id': 2267106556,
#   'node_id': 'PR_kwDOAA0YD85t6Yfc',
#   'number': 58458,
#   'title': 'CI: fix CI failure for PDEP with status: Draft',
#   'user': {'login': 'Aloqeely',
#    'id': 52792999,
#    'node_id': 'MDQ6VXNlcjUyNzkyOTk5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52792999?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Aloqeely',
#    'html_url': 'https://github.com/Aloqeely',
#    'followers_url': 'https://api.github.com/users/Aloqeely/followers',
#    'following_url': 'https://api.github.com/users/Aloqeely/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Aloqeely/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Aloqeely/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Aloqeely/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Aloqeely/orgs',
#    'repos_url': 'https://api.github.com/users/Aloqeely/repos',
#    'events_url': 'https://api.github.com/users/Aloqeely/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Aloqeely/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-04-27T17:19:27Z',
#   'updated_at': '2024-04-27T20:39:05Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58458',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58458',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58458.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58458.patch',
#    'merged_at': None},
#   'body': 'cc @WillAyd \r\n\r\nThis will only fix the CI failure, but 2 things to note:\r\n1- The PDEP won\'t be shown in https://pandas.pydata.org/about/roadmap.html\r\n2- If the PR gets the PDEP label, it will be considered as "Under Discussion" in the website roadmap\r\nI want to fix that, but how will we differentiate? Do we check if the PR is marked as Draft? Or do we check if the PR has a certain label? (e.g. make a PDEP: draft label or use the needs discussion label)\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58458/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58458/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58455',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58455/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58455/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58455/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/58455',
#   'id': 2267087192,
#   'node_id': 'PR_kwDOAA0YD85t6UbA',
#   'number': 58455,
#   'title': 'PDEP-13: The pandas Logical Type System',
#   'user': {'login': 'WillAyd',
#    'id': 609873,
#    'node_id': 'MDQ6VXNlcjYwOTg3Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/609873?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WillAyd',
#    'html_url': 'https://github.com/WillAyd',
#    'followers_url': 'https://api.github.com/users/WillAyd/followers',
#    'following_url': 'https://api.github.com/users/WillAyd/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/WillAyd/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/WillAyd/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/WillAyd/subscriptions',
#    'organizations_url': 'https://api.github.com/users/WillAyd/orgs',
#    'repos_url': 'https://api.github.com/users/WillAyd/repos',
#    'events_url': 'https://api.github.com/users/WillAyd/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/WillAyd/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 4253279386,
#     'node_id': 'LA_kwDOAA0YD879g-Sa',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/PDEP',
#     'name': 'PDEP',
#     'color': '4B02F8',
#     'default': False,
#     'description': 'pandas enhancement proposal'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2024-04-27T16:36:59Z',
#   'updated_at': '2024-04-29T20:08:55Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/58455',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/58455',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/58455.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/58455.patch',
#    'merged_at': None},
#   'body': '@pandas-dev/pandas-core ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58455/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/58455/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(df6)
# Out:
# 30

# %%
for i in range(len(df6)):
    # print(df6[i])
    print(df6[i]["user"])
# Out:
# {'login': 'tuhinsharma121', 'id': 6801780, 'node_id': 'MDQ6VXNlcjY4MDE3ODA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tuhinsharma121', 'html_url': 'https://github.com/tuhinsharma121', 'followers_url': 'https://api.github.com/users/tuhinsharma121/followers', 'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}', 'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions', 'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs', 'repos_url': 'https://api.github.com/users/tuhinsharma121/repos', 'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'tuhinsharma121', 'id': 6801780, 'node_id': 'MDQ6VXNlcjY4MDE3ODA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tuhinsharma121', 'html_url': 'https://github.com/tuhinsharma121', 'followers_url': 'https://api.github.com/users/tuhinsharma121/followers', 'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}', 'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions', 'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs', 'repos_url': 'https://api.github.com/users/tuhinsharma121/repos', 'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'tuhinsharma121', 'id': 6801780, 'node_id': 'MDQ6VXNlcjY4MDE3ODA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tuhinsharma121', 'html_url': 'https://github.com/tuhinsharma121', 'followers_url': 'https://api.github.com/users/tuhinsharma121/followers', 'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}', 'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions', 'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs', 'repos_url': 'https://api.github.com/users/tuhinsharma121/repos', 'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'tuhinsharma121', 'id': 6801780, 'node_id': 'MDQ6VXNlcjY4MDE3ODA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tuhinsharma121', 'html_url': 'https://github.com/tuhinsharma121', 'followers_url': 'https://api.github.com/users/tuhinsharma121/followers', 'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}', 'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions', 'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs', 'repos_url': 'https://api.github.com/users/tuhinsharma121/repos', 'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'tuhinsharma121', 'id': 6801780, 'node_id': 'MDQ6VXNlcjY4MDE3ODA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tuhinsharma121', 'html_url': 'https://github.com/tuhinsharma121', 'followers_url': 'https://api.github.com/users/tuhinsharma121/followers', 'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}', 'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions', 'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs', 'repos_url': 'https://api.github.com/users/tuhinsharma121/repos', 'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'edbennett', 'id': 1698405, 'node_id': 'MDQ6VXNlcjE2OTg0MDU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1698405?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/edbennett', 'html_url': 'https://github.com/edbennett', 'followers_url': 'https://api.github.com/users/edbennett/followers', 'following_url': 'https://api.github.com/users/edbennett/following{/other_user}', 'gists_url': 'https://api.github.com/users/edbennett/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/edbennett/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/edbennett/subscriptions', 'organizations_url': 'https://api.github.com/users/edbennett/orgs', 'repos_url': 'https://api.github.com/users/edbennett/repos', 'events_url': 'https://api.github.com/users/edbennett/events{/privacy}', 'received_events_url': 'https://api.github.com/users/edbennett/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'edbennett', 'id': 1698405, 'node_id': 'MDQ6VXNlcjE2OTg0MDU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1698405?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/edbennett', 'html_url': 'https://github.com/edbennett', 'followers_url': 'https://api.github.com/users/edbennett/followers', 'following_url': 'https://api.github.com/users/edbennett/following{/other_user}', 'gists_url': 'https://api.github.com/users/edbennett/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/edbennett/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/edbennett/subscriptions', 'organizations_url': 'https://api.github.com/users/edbennett/orgs', 'repos_url': 'https://api.github.com/users/edbennett/repos', 'events_url': 'https://api.github.com/users/edbennett/events{/privacy}', 'received_events_url': 'https://api.github.com/users/edbennett/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'tuhinsharma121', 'id': 6801780, 'node_id': 'MDQ6VXNlcjY4MDE3ODA=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6801780?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tuhinsharma121', 'html_url': 'https://github.com/tuhinsharma121', 'followers_url': 'https://api.github.com/users/tuhinsharma121/followers', 'following_url': 'https://api.github.com/users/tuhinsharma121/following{/other_user}', 'gists_url': 'https://api.github.com/users/tuhinsharma121/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tuhinsharma121/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tuhinsharma121/subscriptions', 'organizations_url': 'https://api.github.com/users/tuhinsharma121/orgs', 'repos_url': 'https://api.github.com/users/tuhinsharma121/repos', 'events_url': 'https://api.github.com/users/tuhinsharma121/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tuhinsharma121/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'Tishj', 'id': 17162323, 'node_id': 'MDQ6VXNlcjE3MTYyMzIz', 'avatar_url': 'https://avatars.githubusercontent.com/u/17162323?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Tishj', 'html_url': 'https://github.com/Tishj', 'followers_url': 'https://api.github.com/users/Tishj/followers', 'following_url': 'https://api.github.com/users/Tishj/following{/other_user}', 'gists_url': 'https://api.github.com/users/Tishj/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Tishj/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Tishj/subscriptions', 'organizations_url': 'https://api.github.com/users/Tishj/orgs', 'repos_url': 'https://api.github.com/users/Tishj/repos', 'events_url': 'https://api.github.com/users/Tishj/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Tishj/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'QuLogic', 'id': 302469, 'node_id': 'MDQ6VXNlcjMwMjQ2OQ==', 'avatar_url': 'https://avatars.githubusercontent.com/u/302469?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/QuLogic', 'html_url': 'https://github.com/QuLogic', 'followers_url': 'https://api.github.com/users/QuLogic/followers', 'following_url': 'https://api.github.com/users/QuLogic/following{/other_user}', 'gists_url': 'https://api.github.com/users/QuLogic/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/QuLogic/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/QuLogic/subscriptions', 'organizations_url': 'https://api.github.com/users/QuLogic/orgs', 'repos_url': 'https://api.github.com/users/QuLogic/repos', 'events_url': 'https://api.github.com/users/QuLogic/events{/privacy}', 'received_events_url': 'https://api.github.com/users/QuLogic/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'lithomas1', 'id': 47963215, 'node_id': 'MDQ6VXNlcjQ3OTYzMjE1', 'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lithomas1', 'html_url': 'https://github.com/lithomas1', 'followers_url': 'https://api.github.com/users/lithomas1/followers', 'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}', 'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions', 'organizations_url': 'https://api.github.com/users/lithomas1/orgs', 'repos_url': 'https://api.github.com/users/lithomas1/repos', 'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lithomas1/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'sfc-gh-vbudati', 'id': 136361283, 'node_id': 'U_kgDOCCC1Qw', 'avatar_url': 'https://avatars.githubusercontent.com/u/136361283?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/sfc-gh-vbudati', 'html_url': 'https://github.com/sfc-gh-vbudati', 'followers_url': 'https://api.github.com/users/sfc-gh-vbudati/followers', 'following_url': 'https://api.github.com/users/sfc-gh-vbudati/following{/other_user}', 'gists_url': 'https://api.github.com/users/sfc-gh-vbudati/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/sfc-gh-vbudati/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/sfc-gh-vbudati/subscriptions', 'organizations_url': 'https://api.github.com/users/sfc-gh-vbudati/orgs', 'repos_url': 'https://api.github.com/users/sfc-gh-vbudati/repos', 'events_url': 'https://api.github.com/users/sfc-gh-vbudati/events{/privacy}', 'received_events_url': 'https://api.github.com/users/sfc-gh-vbudati/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'phofl', 'id': 61934744, 'node_id': 'MDQ6VXNlcjYxOTM0NzQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/phofl', 'html_url': 'https://github.com/phofl', 'followers_url': 'https://api.github.com/users/phofl/followers', 'following_url': 'https://api.github.com/users/phofl/following{/other_user}', 'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions', 'organizations_url': 'https://api.github.com/users/phofl/orgs', 'repos_url': 'https://api.github.com/users/phofl/repos', 'events_url': 'https://api.github.com/users/phofl/events{/privacy}', 'received_events_url': 'https://api.github.com/users/phofl/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'jacob-a-brown', 'id': 29125483, 'node_id': 'MDQ6VXNlcjI5MTI1NDgz', 'avatar_url': 'https://avatars.githubusercontent.com/u/29125483?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jacob-a-brown', 'html_url': 'https://github.com/jacob-a-brown', 'followers_url': 'https://api.github.com/users/jacob-a-brown/followers', 'following_url': 'https://api.github.com/users/jacob-a-brown/following{/other_user}', 'gists_url': 'https://api.github.com/users/jacob-a-brown/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jacob-a-brown/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jacob-a-brown/subscriptions', 'organizations_url': 'https://api.github.com/users/jacob-a-brown/orgs', 'repos_url': 'https://api.github.com/users/jacob-a-brown/repos', 'events_url': 'https://api.github.com/users/jacob-a-brown/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jacob-a-brown/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'aBiR1D', 'id': 56883085, 'node_id': 'MDQ6VXNlcjU2ODgzMDg1', 'avatar_url': 'https://avatars.githubusercontent.com/u/56883085?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/aBiR1D', 'html_url': 'https://github.com/aBiR1D', 'followers_url': 'https://api.github.com/users/aBiR1D/followers', 'following_url': 'https://api.github.com/users/aBiR1D/following{/other_user}', 'gists_url': 'https://api.github.com/users/aBiR1D/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/aBiR1D/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/aBiR1D/subscriptions', 'organizations_url': 'https://api.github.com/users/aBiR1D/orgs', 'repos_url': 'https://api.github.com/users/aBiR1D/repos', 'events_url': 'https://api.github.com/users/aBiR1D/events{/privacy}', 'received_events_url': 'https://api.github.com/users/aBiR1D/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'randolf-scholz', 'id': 39696536, 'node_id': 'MDQ6VXNlcjM5Njk2NTM2', 'avatar_url': 'https://avatars.githubusercontent.com/u/39696536?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/randolf-scholz', 'html_url': 'https://github.com/randolf-scholz', 'followers_url': 'https://api.github.com/users/randolf-scholz/followers', 'following_url': 'https://api.github.com/users/randolf-scholz/following{/other_user}', 'gists_url': 'https://api.github.com/users/randolf-scholz/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/randolf-scholz/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/randolf-scholz/subscriptions', 'organizations_url': 'https://api.github.com/users/randolf-scholz/orgs', 'repos_url': 'https://api.github.com/users/randolf-scholz/repos', 'events_url': 'https://api.github.com/users/randolf-scholz/events{/privacy}', 'received_events_url': 'https://api.github.com/users/randolf-scholz/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'sfo', 'id': 571497, 'node_id': 'MDQ6VXNlcjU3MTQ5Nw==', 'avatar_url': 'https://avatars.githubusercontent.com/u/571497?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/sfo', 'html_url': 'https://github.com/sfo', 'followers_url': 'https://api.github.com/users/sfo/followers', 'following_url': 'https://api.github.com/users/sfo/following{/other_user}', 'gists_url': 'https://api.github.com/users/sfo/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/sfo/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/sfo/subscriptions', 'organizations_url': 'https://api.github.com/users/sfo/orgs', 'repos_url': 'https://api.github.com/users/sfo/repos', 'events_url': 'https://api.github.com/users/sfo/events{/privacy}', 'received_events_url': 'https://api.github.com/users/sfo/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'covracer', 'id': 8137745, 'node_id': 'MDQ6VXNlcjgxMzc3NDU=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8137745?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/covracer', 'html_url': 'https://github.com/covracer', 'followers_url': 'https://api.github.com/users/covracer/followers', 'following_url': 'https://api.github.com/users/covracer/following{/other_user}', 'gists_url': 'https://api.github.com/users/covracer/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/covracer/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/covracer/subscriptions', 'organizations_url': 'https://api.github.com/users/covracer/orgs', 'repos_url': 'https://api.github.com/users/covracer/repos', 'events_url': 'https://api.github.com/users/covracer/events{/privacy}', 'received_events_url': 'https://api.github.com/users/covracer/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'jorgehv', 'id': 4896554, 'node_id': 'MDQ6VXNlcjQ4OTY1NTQ=', 'avatar_url': 'https://avatars.githubusercontent.com/u/4896554?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jorgehv', 'html_url': 'https://github.com/jorgehv', 'followers_url': 'https://api.github.com/users/jorgehv/followers', 'following_url': 'https://api.github.com/users/jorgehv/following{/other_user}', 'gists_url': 'https://api.github.com/users/jorgehv/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jorgehv/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jorgehv/subscriptions', 'organizations_url': 'https://api.github.com/users/jorgehv/orgs', 'repos_url': 'https://api.github.com/users/jorgehv/repos', 'events_url': 'https://api.github.com/users/jorgehv/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jorgehv/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'Chirawat3987', 'id': 56013599, 'node_id': 'MDQ6VXNlcjU2MDEzNTk5', 'avatar_url': 'https://avatars.githubusercontent.com/u/56013599?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Chirawat3987', 'html_url': 'https://github.com/Chirawat3987', 'followers_url': 'https://api.github.com/users/Chirawat3987/followers', 'following_url': 'https://api.github.com/users/Chirawat3987/following{/other_user}', 'gists_url': 'https://api.github.com/users/Chirawat3987/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Chirawat3987/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Chirawat3987/subscriptions', 'organizations_url': 'https://api.github.com/users/Chirawat3987/orgs', 'repos_url': 'https://api.github.com/users/Chirawat3987/repos', 'events_url': 'https://api.github.com/users/Chirawat3987/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Chirawat3987/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'shriyakalakata', 'id': 87483933, 'node_id': 'MDQ6VXNlcjg3NDgzOTMz', 'avatar_url': 'https://avatars.githubusercontent.com/u/87483933?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/shriyakalakata', 'html_url': 'https://github.com/shriyakalakata', 'followers_url': 'https://api.github.com/users/shriyakalakata/followers', 'following_url': 'https://api.github.com/users/shriyakalakata/following{/other_user}', 'gists_url': 'https://api.github.com/users/shriyakalakata/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/shriyakalakata/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/shriyakalakata/subscriptions', 'organizations_url': 'https://api.github.com/users/shriyakalakata/orgs', 'repos_url': 'https://api.github.com/users/shriyakalakata/repos', 'events_url': 'https://api.github.com/users/shriyakalakata/events{/privacy}', 'received_events_url': 'https://api.github.com/users/shriyakalakata/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'natmokval', 'id': 91160475, 'node_id': 'MDQ6VXNlcjkxMTYwNDc1', 'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/natmokval', 'html_url': 'https://github.com/natmokval', 'followers_url': 'https://api.github.com/users/natmokval/followers', 'following_url': 'https://api.github.com/users/natmokval/following{/other_user}', 'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions', 'organizations_url': 'https://api.github.com/users/natmokval/orgs', 'repos_url': 'https://api.github.com/users/natmokval/repos', 'events_url': 'https://api.github.com/users/natmokval/events{/privacy}', 'received_events_url': 'https://api.github.com/users/natmokval/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'TsiVit', 'id': 40140211, 'node_id': 'MDQ6VXNlcjQwMTQwMjEx', 'avatar_url': 'https://avatars.githubusercontent.com/u/40140211?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/TsiVit', 'html_url': 'https://github.com/TsiVit', 'followers_url': 'https://api.github.com/users/TsiVit/followers', 'following_url': 'https://api.github.com/users/TsiVit/following{/other_user}', 'gists_url': 'https://api.github.com/users/TsiVit/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/TsiVit/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/TsiVit/subscriptions', 'organizations_url': 'https://api.github.com/users/TsiVit/orgs', 'repos_url': 'https://api.github.com/users/TsiVit/repos', 'events_url': 'https://api.github.com/users/TsiVit/events{/privacy}', 'received_events_url': 'https://api.github.com/users/TsiVit/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'iangainey', 'id': 109095667, 'node_id': 'U_kgDOBoCq8w', 'avatar_url': 'https://avatars.githubusercontent.com/u/109095667?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/iangainey', 'html_url': 'https://github.com/iangainey', 'followers_url': 'https://api.github.com/users/iangainey/followers', 'following_url': 'https://api.github.com/users/iangainey/following{/other_user}', 'gists_url': 'https://api.github.com/users/iangainey/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/iangainey/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/iangainey/subscriptions', 'organizations_url': 'https://api.github.com/users/iangainey/orgs', 'repos_url': 'https://api.github.com/users/iangainey/repos', 'events_url': 'https://api.github.com/users/iangainey/events{/privacy}', 'received_events_url': 'https://api.github.com/users/iangainey/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'BdR76', 'id': 7793956, 'node_id': 'MDQ6VXNlcjc3OTM5NTY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/7793956?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/BdR76', 'html_url': 'https://github.com/BdR76', 'followers_url': 'https://api.github.com/users/BdR76/followers', 'following_url': 'https://api.github.com/users/BdR76/following{/other_user}', 'gists_url': 'https://api.github.com/users/BdR76/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/BdR76/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/BdR76/subscriptions', 'organizations_url': 'https://api.github.com/users/BdR76/orgs', 'repos_url': 'https://api.github.com/users/BdR76/repos', 'events_url': 'https://api.github.com/users/BdR76/events{/privacy}', 'received_events_url': 'https://api.github.com/users/BdR76/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'BdR76', 'id': 7793956, 'node_id': 'MDQ6VXNlcjc3OTM5NTY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/7793956?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/BdR76', 'html_url': 'https://github.com/BdR76', 'followers_url': 'https://api.github.com/users/BdR76/followers', 'following_url': 'https://api.github.com/users/BdR76/following{/other_user}', 'gists_url': 'https://api.github.com/users/BdR76/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/BdR76/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/BdR76/subscriptions', 'organizations_url': 'https://api.github.com/users/BdR76/orgs', 'repos_url': 'https://api.github.com/users/BdR76/repos', 'events_url': 'https://api.github.com/users/BdR76/events{/privacy}', 'received_events_url': 'https://api.github.com/users/BdR76/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'jowens', 'id': 976970, 'node_id': 'MDQ6VXNlcjk3Njk3MA==', 'avatar_url': 'https://avatars.githubusercontent.com/u/976970?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jowens', 'html_url': 'https://github.com/jowens', 'followers_url': 'https://api.github.com/users/jowens/followers', 'following_url': 'https://api.github.com/users/jowens/following{/other_user}', 'gists_url': 'https://api.github.com/users/jowens/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jowens/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jowens/subscriptions', 'organizations_url': 'https://api.github.com/users/jowens/orgs', 'repos_url': 'https://api.github.com/users/jowens/repos', 'events_url': 'https://api.github.com/users/jowens/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jowens/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'jorisvandenbossche', 'id': 1020496, 'node_id': 'MDQ6VXNlcjEwMjA0OTY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jorisvandenbossche', 'html_url': 'https://github.com/jorisvandenbossche', 'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers', 'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}', 'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions', 'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs', 'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos', 'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'Aloqeely', 'id': 52792999, 'node_id': 'MDQ6VXNlcjUyNzkyOTk5', 'avatar_url': 'https://avatars.githubusercontent.com/u/52792999?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Aloqeely', 'html_url': 'https://github.com/Aloqeely', 'followers_url': 'https://api.github.com/users/Aloqeely/followers', 'following_url': 'https://api.github.com/users/Aloqeely/following{/other_user}', 'gists_url': 'https://api.github.com/users/Aloqeely/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Aloqeely/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Aloqeely/subscriptions', 'organizations_url': 'https://api.github.com/users/Aloqeely/orgs', 'repos_url': 'https://api.github.com/users/Aloqeely/repos', 'events_url': 'https://api.github.com/users/Aloqeely/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Aloqeely/received_events', 'type': 'User', 'site_admin': False}
# {'login': 'WillAyd', 'id': 609873, 'node_id': 'MDQ6VXNlcjYwOTg3Mw==', 'avatar_url': 'https://avatars.githubusercontent.com/u/609873?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/WillAyd', 'html_url': 'https://github.com/WillAyd', 'followers_url': 'https://api.github.com/users/WillAyd/followers', 'following_url': 'https://api.github.com/users/WillAyd/following{/other_user}', 'gists_url': 'https://api.github.com/users/WillAyd/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/WillAyd/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/WillAyd/subscriptions', 'organizations_url': 'https://api.github.com/users/WillAyd/orgs', 'repos_url': 'https://api.github.com/users/WillAyd/repos', 'events_url': 'https://api.github.com/users/WillAyd/events{/privacy}', 'received_events_url': 'https://api.github.com/users/WillAyd/received_events', 'type': 'User', 'site_admin': False}
