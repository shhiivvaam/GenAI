# %%
# Seaborn: Statistical Data Visualization 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Numerical Data Plotting

# Rel Plot >> It help understand the relationship between two variables
sns.relplot()
sns.relplot
# Out:
# <function seaborn.relational.relplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, units=None, weights=None, row=None, col=None, col_wrap=None, row_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None, dashes=None, style_order=None, legend='auto', kind='scatter', height=5, aspect=1, facet_kws=None, **kwargs)>

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df)

# %%
sns.scatterplot(x = df.total_bill, y = df.tip, data = df)               # This tells us that: higher the bill heigher the tip
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = df.total_bill, y = df.tip, data = df, hue = 'smoker')    # Using { hue } : We can get the data bifirction that the person is smoker or not
                                                                            # Also we get the insight that: The heighest tip was given by a smoker
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, hue = 'smoker')          # This is a scatter plot with the desired result and the nature of { relplot() }

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, style = 'size')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = df, style ='smoker', hue = 'time')     # style is the marker
                                                                                        # hue is the color

# %%
value = np.random.randn(100)
time = np.arange(100)
df = pd.DataFrame(time, value.cumsum())
df
# Out:
#              0
# -2.436621    0
# -2.292204    1
# -2.842255    2
# -2.657264    3
# -1.303969    4
# ...         ..
#  10.259068  95
#  12.002654  96
#  11.209188  97
#  10.309746  98
#  10.352631  99
#
# [100 rows x 1 columns]

# %%
time = np.arange(500)
value = np.random.randn(500).cumsum()
df = pd.DataFrame({'time' : time, 'value' : value})
df
# Out:
#      time      value
# 0       0  -0.160227
# 1       1   0.126265
# 2       2   0.207998
# 3       3   0.234608
# 4       4   0.392609
# ..    ...        ...
# 495   495 -18.497520
# 496   496 -19.216011
# 497   497 -20.529776
# 498   498 -21.571686
# 499   499 -21.450728
#
# [500 rows x 2 columns]

# %%
# sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = True)
sns.relplot(x = time, y = value, kind = 'line', data = df, sort = True)

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci='sd')     # ci = confidence interval, sd = standard deviation
                                                                                # The light_blue area's width around the plotted blue line, increases to the standard devation
# Out:
# C:\Users\lifes\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci='sd', estimator = None)   # estimator : this will remove the spreaded region and will spread the lines accordingly
# Out:
# C:\Users\lifes\AppData\Roaming\Python\Python312\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, hue = 'event')

# %%
from matplotlib.pyplot import errorbar


sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, errorbar='sd', estimator = None, hue = 'event')                      # ci = errorbar : confidence interval

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, hue = 'event', style = 'region', markers=True, dashes = False)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', data = sns.load_dataset('tips'), col = 'time')

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', data = sns.load_dataset('tips'), col = 'size')

# %%
# Catplot

sns.catplot(x = 'day', y = 'total_bill', data = sns.load_dataset('tips'))         # here it shows the day wise distribution of the total bill

# %%
# Catplot -> kind 'swarm'

sns.catplot(x = 'day', y = 'total_bill', data = sns.load_dataset('tips'), kind = 'swarm')

# %%
# Catplot   -> BoxPlot

sns.catplot(x = 'day', y = 'total_bill', data = sns.load_dataset('tips'), kind = 'box')

# %%
# Catplot  -> Boxe type plot

sns.catplot(x = 'day', y = 'total_bill', data = sns.load_dataset('tips'), kind = 'boxen')

# %%
# Catplot  -> 'violin'

sns.catplot(x = 'day', y = 'total_bill', data = sns.load_dataset('tips'), kind = 'violin')

# %%
sns.barplot(x = 'day', y = 'total_bill', data = sns.load_dataset('tips'))
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Joint Plot :  Draw a plot of two variables with bivariate and univariate graphs

tips = sns.load_dataset('tips')
sns.jointplot(x = tips.total_bill, y = tips.tip)                 # The sctter points, tells about the distribution of the two variables, and the bar plot tells about the remaining distribution data

# %%
# Regression line - in Joint plot

# Putting the BEST FIT LINE
sns.jointplot(x = tips.total_bill, y = tips.tip, kind = 'reg')          # kind = 'reg'  : regression : it adds the regression line to the graph

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip, kind = 'hex')          # hex : hexagon

# %%
# Contour Plot          -> This is very much used by the { Metrological Department -> for estimating the center points for: tsunami, earthquake, etc}

sns.jointplot(x = tips.total_bill, y = tips.tip, kind = 'kde')        # kde : kernel density estimator/ estimation

# %%
# pairplot   >>  it will plot all the pair wise relationship btw dataframes

# It is used to get the knowledge of multiple features
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue ='smoker')

# %%
sns.pairplot(tips, hue = 'smoker', palette = 'coolwarm')

# %%
# Box Plot

sns.boxplot(x = 'day', y = 'total_bill', data = tips, palette = 'rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, palette = 'rainbow', orient = 'h')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data = tips, palette = 'rainbow', orient = 'h')
# Out:
# <Axes: >

# %%
# Correlation

tips = tips[['total_bill', 'tip', 'size']]        # taking only the numeric values
tips.corr()    # Just using this will, raise an error for th String(object) type of variables
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
sns.heatmap(tips.corr(), cmap = 'coolwarm', annot = True)
# Out:
# <Axes: >

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x = 'sex', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, height = 15)

# %%
# sns.lmplot(x = 'total_bill', y = 'tip', data = tips, aspect = 1)
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, height = 15, aspect = 0.5)       #aspect to (zoom - in/out the graph)
